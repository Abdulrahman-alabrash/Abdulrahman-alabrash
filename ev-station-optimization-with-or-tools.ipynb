# %% [markdown]
# <a href="https://www.kaggle.com/code/abdulrahmanalabrash/ev-station-optimization-with-or-tools?scriptVersionId=174263597" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
#  # ChargeWise Navigator: A Strategic Model for Optimizing Electric Vehicle Refueling Locations with OR Tools

# %% [markdown]
# ## Import required libraries

# %%
from ortools.linear_solver import pywraplp
from itertools import product
import pandas as pd
import folium
from itertools import combinations
solver = pywraplp.Solver.CreateSolver('SCIP')

# %%
# Read the CSV file with latitude and longitude data

data_izmir = pd.read_csv('/kaggle/input/optimization-using-or/Copy of zmir_Stations - Sheet1.csv')

toll_data= pd.read_csv('/kaggle/input/optimization-using-or/Name of the tolls.csv')


# Extract latitude and longitude columns from the DataFrame
latitudes = data_izmir['Latitude']
longitudes = data_izmir['Longitude']

Lat=toll_data['lat']
Lon=toll_data['lon']

# Create a list of existing gas station locations
existing_stations = list(zip(latitudes, longitudes))
toll_data
# Out:
#                      Name         lat        lon
# 0        Şehitlik Gişeleri  26.993470  38.397191
# 1     Seferihisar Gişeleri  26.871305  38.365339
# 2              Urla Gişesi  26.781988  38.322773
# 3       Karaburun Gişeleri  26.686092  38.303068
# 4         Zeytinler Gişesi  26.564120  38.285035
# 5         Alaçatı Gişeleri  26.382368  38.280521
# 6           Çeşme Gişeleri  26.310192  38.295976
# 7   Işıkkent Gişeler Taksi  27.233711  38.351512
# 8      Tahtalıçay Gişeleri  27.217107  38.272651
# 9         Torbalı Gişeleri  27.338020  38.194293
# 10            Belevi Tolls  27.449425  38.028354
# 11        Germencik Gişesi  27.578095  37.878091
# 12               ŞEVKETİYE  27.838241  37.839819
# 13                 Balçova  27.058170  38.384617
# 14                Gaziemir  27.122520  38.325150
# 15              OTOYOL AYR  27.226190  38.440201
# 16         ÜNİVERSİTE AYR.  27.158234  38.481145
# 17               KARŞIYAKA  27.036677  38.548843
# 18                     End  27.916824  37.847296

# %% [markdown]
# ## Defining lists and parameters

# %%
# Set of Potential Stations 
K = ["ÇEŞME", "URLA", "SEFERIHISAR", "GAZIEMIR", "TAHTALIÇAY", "OTOYOLAYR",  "KARŞIYAKA", "BELEVI", "GERMENCIK", "ŞEVKETIYE"]

# Set of all OD pairs
Q = ["ÇEŞME-ALAÇATI-ZEYTINLER", "ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN", "ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA", "ALAÇATI-ZEYTNILER-KARABURUN", "ALAÇATI-ZEYTNILER-KARABURUN-URLA", "ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR", "ZEYTNILER-KARABURUN-URLA", "ZEYTNILER-KARABURUN-URLA-SEFERIHISAR", "ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK", "KARABURUN-URLA-SEFERIHISAR", "KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK", "KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA", "URLA-SEFERIHISAR-ŞEHITLIK", "URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA", "URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR", "SEFERIHISAR-ŞEHITLIK-BALÇOVA", "SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR", "SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR", "ŞEHITLIK-BALÇOVA-GAZIEMIR", "ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR", "ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT", "BALÇOVA-GAZIEMIR-OTOYOLAYR", "BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT", "BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY", "ŞEVKETİYE-GERMENCIK-BELEVI", "ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI", "ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY"]
# flow volume on the OD pair qQ = ["ALAÇATI-KARABURUN", "ALAÇATI-KARABURUN-SEFERHISAR", "ALAÇATI-KARABURUN-SEFERHISAR-OTOYOL AYR.", "KARABURUN-SEFERHISAR", "KARABURUN-SEFERHISAR-OTOYOL AYR.", "KARABURUN-SEFERHISAR-OTOYOL AYR.-ÜNIVERSITE AYR.", "SEFERHISAR-OTOYOL AYR.", "SEFERHISAR-OTOYOL AYR.-ÜNIVERSITE AYR.", "SEFERHISAR-OTOYOL AYR.-ÜNIVERSITE AYR.-TORBALI", "OTOYOL AYR.-ÜNIVERSITE AYR", "OTOYOL AYR.-ÜNIVERSITE AYR-TORBALI", "OTOYOL AYR.-ÜNIVERSITE AYR-TORBALI-GERMENCIK", "ÜNIVERSITE AYR.-TORBALI", "ÜNIVERSITE AYR.-TORBALI-GERMENCIK", "ÜNIVERSITE AYR.-TORBALI-GERMENCIK-SEVKETIYE"
f = [8235, 9173, 9926, 11606, 12285, 18276, 12520, 22538, 19950, 22917, 31085, 32599, 33345, 37703, 41779, 45495, 48642, 53071, 50777, 55778, 55715, 59881, 58808, 55010, 24441, 27419, 30014]
# the number of stations to be opened
P = 4
C ={}
for k in K: 
    for q in Q:
        if k in q:
            C[k,q]= 1
        else:
            C[k,q] = 0
C
# Out:
# {('ÇEŞME', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 1,
#  ('ÇEŞME', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 1,
#  ('ÇEŞME', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 1,
#  ('ÇEŞME', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('ÇEŞME', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('ÇEŞME', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('ÇEŞME', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('ÇEŞME', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('ÇEŞME', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('ÇEŞME', 'KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('ÇEŞME', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('ÇEŞME', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('ÇEŞME', 'URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('ÇEŞME', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('ÇEŞME', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('ÇEŞME', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('ÇEŞME', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('ÇEŞME', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('ÇEŞME', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('ÇEŞME', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('ÇEŞME', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('ÇEŞME', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('ÇEŞME', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('ÇEŞME', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 0,
#  ('ÇEŞME', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 0,
#  ('ÇEŞME', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 0,
#  ('ÇEŞME', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 0,
#  ('URLA', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('URLA', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('URLA', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 1,
#  ('URLA', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('URLA', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 1,
#  ('URLA', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 1,
#  ('URLA', 'ZEYTNILER-KARABURUN-URLA'): 1,
#  ('URLA', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 1,
#  ('URLA', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 1,
#  ('URLA', 'KARABURUN-URLA-SEFERIHISAR'): 1,
#  ('URLA', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 1,
#  ('URLA', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 1,
#  ('URLA', 'URLA-SEFERIHISAR-ŞEHITLIK'): 1,
#  ('URLA', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 1,
#  ('URLA', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 1,
#  ('URLA', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('URLA', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('URLA', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('URLA', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('URLA', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('URLA', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('URLA', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('URLA', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('URLA', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 0,
#  ('URLA', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 0,
#  ('URLA', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 0,
#  ('URLA', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 0,
#  ('SEFERIHISAR', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('SEFERIHISAR', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('SEFERIHISAR', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 0,
#  ('SEFERIHISAR', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('SEFERIHISAR', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('SEFERIHISAR', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 1,
#  ('SEFERIHISAR', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('SEFERIHISAR', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 1,
#  ('SEFERIHISAR', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 1,
#  ('SEFERIHISAR', 'KARABURUN-URLA-SEFERIHISAR'): 1,
#  ('SEFERIHISAR', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 1,
#  ('SEFERIHISAR', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 1,
#  ('SEFERIHISAR', 'URLA-SEFERIHISAR-ŞEHITLIK'): 1,
#  ('SEFERIHISAR', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 1,
#  ('SEFERIHISAR', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 1,
#  ('SEFERIHISAR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 1,
#  ('SEFERIHISAR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 1,
#  ('SEFERIHISAR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 1,
#  ('SEFERIHISAR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('SEFERIHISAR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('SEFERIHISAR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('SEFERIHISAR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('SEFERIHISAR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('SEFERIHISAR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 0,
#  ('SEFERIHISAR', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 0,
#  ('SEFERIHISAR', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 0,
#  ('SEFERIHISAR', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 0,
#  ('GAZIEMIR', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('GAZIEMIR', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('GAZIEMIR', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 0,
#  ('GAZIEMIR', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('GAZIEMIR', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('GAZIEMIR', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('GAZIEMIR', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('GAZIEMIR', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('GAZIEMIR', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('GAZIEMIR', 'KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('GAZIEMIR', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('GAZIEMIR', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('GAZIEMIR', 'URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('GAZIEMIR', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('GAZIEMIR', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 1,
#  ('GAZIEMIR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('GAZIEMIR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 1,
#  ('GAZIEMIR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 1,
#  ('GAZIEMIR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 1,
#  ('GAZIEMIR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 1,
#  ('GAZIEMIR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 1,
#  ('GAZIEMIR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 1,
#  ('GAZIEMIR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 1,
#  ('GAZIEMIR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 1,
#  ('GAZIEMIR', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 0,
#  ('GAZIEMIR', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 0,
#  ('GAZIEMIR', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 0,
#  ('TAHTALIÇAY', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('TAHTALIÇAY', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('TAHTALIÇAY', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 0,
#  ('TAHTALIÇAY', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('TAHTALIÇAY', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('TAHTALIÇAY', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('TAHTALIÇAY', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('TAHTALIÇAY', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('TAHTALIÇAY', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('TAHTALIÇAY', 'KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('TAHTALIÇAY', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('TAHTALIÇAY', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('TAHTALIÇAY', 'URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('TAHTALIÇAY', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('TAHTALIÇAY', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('TAHTALIÇAY', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('TAHTALIÇAY', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('TAHTALIÇAY', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('TAHTALIÇAY', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('TAHTALIÇAY', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('TAHTALIÇAY', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('TAHTALIÇAY', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('TAHTALIÇAY', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('TAHTALIÇAY', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 1,
#  ('TAHTALIÇAY', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 0,
#  ('TAHTALIÇAY', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 0,
#  ('TAHTALIÇAY', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 0,
#  ('OTOYOLAYR', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('OTOYOLAYR', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('OTOYOLAYR', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 0,
#  ('OTOYOLAYR', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('OTOYOLAYR', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('OTOYOLAYR', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('OTOYOLAYR', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('OTOYOLAYR', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('OTOYOLAYR', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('OTOYOLAYR', 'KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('OTOYOLAYR', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('OTOYOLAYR', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('OTOYOLAYR', 'URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('OTOYOLAYR', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('OTOYOLAYR', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('OTOYOLAYR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('OTOYOLAYR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('OTOYOLAYR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 1,
#  ('OTOYOLAYR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('OTOYOLAYR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 1,
#  ('OTOYOLAYR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 1,
#  ('OTOYOLAYR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 1,
#  ('OTOYOLAYR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 1,
#  ('OTOYOLAYR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 1,
#  ('OTOYOLAYR', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 0,
#  ('OTOYOLAYR', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 0,
#  ('OTOYOLAYR', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 0,
#  ('KARŞIYAKA', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('KARŞIYAKA', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('KARŞIYAKA', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 0,
#  ('KARŞIYAKA', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('KARŞIYAKA', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('KARŞIYAKA', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('KARŞIYAKA', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('KARŞIYAKA', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('KARŞIYAKA', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('KARŞIYAKA', 'KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('KARŞIYAKA', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('KARŞIYAKA', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('KARŞIYAKA', 'URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('KARŞIYAKA', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('KARŞIYAKA', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('KARŞIYAKA', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('KARŞIYAKA', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('KARŞIYAKA', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('KARŞIYAKA', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('KARŞIYAKA', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('KARŞIYAKA', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('KARŞIYAKA', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('KARŞIYAKA', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('KARŞIYAKA', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 0,
#  ('KARŞIYAKA', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 0,
#  ('KARŞIYAKA', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 0,
#  ('KARŞIYAKA', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 0,
#  ('BELEVI', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('BELEVI', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('BELEVI', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 0,
#  ('BELEVI', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('BELEVI', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('BELEVI', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('BELEVI', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('BELEVI', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('BELEVI', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('BELEVI', 'KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('BELEVI', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('BELEVI', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('BELEVI', 'URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('BELEVI', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('BELEVI', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('BELEVI', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('BELEVI', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('BELEVI', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('BELEVI', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('BELEVI', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('BELEVI', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('BELEVI', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('BELEVI', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('BELEVI', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 0,
#  ('BELEVI', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 1,
#  ('BELEVI', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 1,
#  ('BELEVI', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 1,
#  ('GERMENCIK', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('GERMENCIK', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('GERMENCIK', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 0,
#  ('GERMENCIK', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('GERMENCIK', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('GERMENCIK', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('GERMENCIK', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('GERMENCIK', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('GERMENCIK', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('GERMENCIK', 'KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('GERMENCIK', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('GERMENCIK', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('GERMENCIK', 'URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('GERMENCIK', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('GERMENCIK', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('GERMENCIK', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('GERMENCIK', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('GERMENCIK', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('GERMENCIK', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('GERMENCIK', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('GERMENCIK', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('GERMENCIK', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('GERMENCIK', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('GERMENCIK', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 0,
#  ('GERMENCIK', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 1,
#  ('GERMENCIK', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 1,
#  ('GERMENCIK', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 1,
#  ('ŞEVKETIYE', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('ŞEVKETIYE', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('ŞEVKETIYE', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 0,
#  ('ŞEVKETIYE', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('ŞEVKETIYE', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('ŞEVKETIYE', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('ŞEVKETIYE', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('ŞEVKETIYE', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('ŞEVKETIYE', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('ŞEVKETIYE', 'KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('ŞEVKETIYE', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('ŞEVKETIYE', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('ŞEVKETIYE', 'URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('ŞEVKETIYE', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('ŞEVKETIYE', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('ŞEVKETIYE', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('ŞEVKETIYE', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('ŞEVKETIYE', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('ŞEVKETIYE', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('ŞEVKETIYE', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('ŞEVKETIYE', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('ŞEVKETIYE', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('ŞEVKETIYE', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('ŞEVKETIYE', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 0,
#  ('ŞEVKETIYE', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 0,
#  ('ŞEVKETIYE', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 0,
#  ('ŞEVKETIYE', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 0}

# %% [markdown]
# ## Defining variables

# %%
# y = 1 If fq is captured otherwise 0
y = {}
for q in Q:
    y[q] = solver.BoolVar(f'y_{q}')
# x = 1 if a station is located at k otherwise 0
x = {}
for k in K:
    x[k] = solver.BoolVar(f'x_{k}')

# %%
# Create a map centered around Izmir
izmir_map = folium.Map(location=[38.4237, 27.1428], zoom_start=9)  # You can adjust the coordinates and zoom level as needed

# Add markers for gas stations
for i in range(len(latitudes)):
    lat = latitudes[i]
    lon = longitudes[i]
    folium.CircleMarker([lat, lon],  color="red", radius=1, weight=2).add_to(izmir_map)  

    
izmir_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e494a24aa7e6a700f70c77244dc66767 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e494a24aa7e6a700f70c77244dc66767&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e494a24aa7e6a700f70c77244dc66767 = L.map(
#                 &quot;map_e494a24aa7e6a700f70c77244dc66767&quot;,
#                 {
#                     center: [38.4237, 27.1428],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f5ebfdf825a476a8d17c0d69d237ed5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_3f5ebfdf825a476a8d17c0d69d237ed5.addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#             var circle_marker_3d2211be5519dcaa15c93e9a1856d77d = L.circleMarker(
#                 [38.3659695, 27.1447331],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_75db6bcc6934d54b818b6557c95ca7eb = L.circleMarker(
#                 [38.4006306, 27.1203472],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_37f3cf9f0339f05c0b9a28840f2651e6 = L.circleMarker(
#                 [38.4263328, 27.1393993],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_ac1020f35343b45e7a465d7dcbf10af3 = L.circleMarker(
#                 [38.4173447, 27.131525],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_6332889f768002e9493542649e75952c = L.circleMarker(
#                 [38.3726707, 27.1649462],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_d323183d2159de5e1fc69297f277aa0d = L.circleMarker(
#                 [38.4463258, 27.1738927],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_1cc996356d9

# %%
point_coordinates = {
    "Şehitlik Gişeleri": (38.397191, 26.99347),
    "Seferihisar Gişeleri": (38.365339, 26.871305),
    "Urla Gişesi": (38.322773, 26.781988),
    "Karaburun Gişeleri": (38.30306799999999, 26.686092),
    "Zeytinler Gişesi": (38.285035, 26.5641199),
    "Alaçatı Gişeleri": (38.280521, 26.3823682),
    "Çeşme Gişeleri": (38.295976, 26.3101921),
    "Işıkkent Gişeler Taksi": (38.3515118, 27.2337111),
    "Tahtalıçay Gişeleri": (38.272651, 27.217107),
    "Torbalı Gişeleri": (38.19429269999999, 27.3380205),
    "Belevi Tolls": (38.0283545, 27.4494247),
    "Germencik Gişesi": (37.878091, 27.5780948),
    "ŞEVKETİYE": (37.8398194, 27.838241),
    "Balçova": (38.3846169, 27.0581702),
    "Gaziemir": (38.32515, 27.12252),
    "OTOYOL AYR": (38.4402007, 27.2261902),
    "ÜNİVERSİTE AYR": (38.4811447, 27.1582345),
    "KARŞIYAKA": (38.5488434, 27.0366772),
    "End": (37.847296, 27.9168236),
}

# Create a map centered around a specific point (e.g., the first point)
map_center = list(point_coordinates.values())[0]

# %%
# Add points to the map
for name, coordinates in point_coordinates.items():
    folium.Marker(location=coordinates, popup=name).add_to(izmir_map)

izmir_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e494a24aa7e6a700f70c77244dc66767 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e494a24aa7e6a700f70c77244dc66767&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e494a24aa7e6a700f70c77244dc66767 = L.map(
#                 &quot;map_e494a24aa7e6a700f70c77244dc66767&quot;,
#                 {
#                     center: [38.4237, 27.1428],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f5ebfdf825a476a8d17c0d69d237ed5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_3f5ebfdf825a476a8d17c0d69d237ed5.addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#             var circle_marker_3d2211be5519dcaa15c93e9a1856d77d = L.circleMarker(
#                 [38.3659695, 27.1447331],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_75db6bcc6934d54b818b6557c95ca7eb = L.circleMarker(
#                 [38.4006306, 27.1203472],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_37f3cf9f0339f05c0b9a28840f2651e6 = L.circleMarker(
#                 [38.4263328, 27.1393993],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_ac1020f35343b45e7a465d7dcbf10af3 = L.circleMarker(
#                 [38.4173447, 27.131525],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_6332889f768002e9493542649e75952c = L.circleMarker(
#                 [38.3726707, 27.1649462],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_d323183d2159de5e1fc69297f277aa0d = L.circleMarker(
#                 [38.4463258, 27.1738927],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_1cc996356d9

# %%
# Define a color mapping function based on car volume
def color_mapping(car_volume):
    if car_volume >= 60:  # Red for busy
        return 'red'
    elif car_volume >= 30:  # Yellow for normal
        return 'yellow'
    else:  # Green for empty
        return 'green'

# Locations and car volumes
locations = [
    (38.2695061, 26.3335397, "ALAÇATI - ÇEŞME", 4.889),
    (38.2699406, 26.4837731, "ZEYTİNLER - ALAÇATI", 11.581),
    (38.2925787, 26.628312, "KARABURUN - ZEYTİNLER", 11.05),
    (38.2995843, 26.7371453, "URLA - KARABURUN", 12.187),
    (38.3416037, 26.8233193, "SEFERİHİSAR - URLA", 14.325),
    (38.3761042, 26.930436, "ŞEHİTLİK - SEFERİHİSAR", 42.24),
    (38.3565197, 27.088229, "BALÇOVA - GAZİEMİR", 58.084),
    (38.3651343, 27.1766346, "GAZİEMİR - OTOYOL AYR.", 70.784),
    (38.4451636, 27.2107121, "OTOYOL AYR. - ÜNİVERSİTE AYR.", 101.826),
    (38.4889367, 27.0874592, "ÜNİVERSİTE AYR. - KARŞIYAKA", 91.069),
    (38.3278117, 27.2364814, "IŞIKKENT - TAHTALIÇAY", 40.396),
    (38.2226299, 27.2518079, "TAHTALIÇAY - TORBALI", 36.351),
    (38.0979131, 27.3747175, "TORBALI - BELEVİ", 26.882),
    (37.9621568, 27.5120466, "BELEVİ - GERMENCİK", 25.128),
    (37.8703384, 27.736923, "GERMENCİK - ŞEVKETİYE", 21.315)
]

# Add markers with car volumes as labels and color-coded based on the mapping function
for location in locations:
    car_volume = location[3]
    color = color_mapping(car_volume)
    folium.Marker(
        location=[location[0], location[1]],
        popup=f"{location[2]}\nNumber of cars: {location[3]}",
        icon=folium.Icon(color=color)
    ).add_to(izmir_map)
izmir_map
# Out:
# /tmp/ipykernel_19/3889126832.py:36: UserWarning: color argument of Icon should be one of: {'black', 'white', 'lightgray', 'purple', 'cadetblue', 'darkred', 'lightgreen', 'darkblue', 'red', 'green', 'lightred', 'darkgreen', 'beige', 'lightblue', 'blue', 'orange', 'pink', 'darkpurple', 'gray'}.
#   icon=folium.Icon(color=color)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e494a24aa7e6a700f70c77244dc66767 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e494a24aa7e6a700f70c77244dc66767&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e494a24aa7e6a700f70c77244dc66767 = L.map(
#                 &quot;map_e494a24aa7e6a700f70c77244dc66767&quot;,
#                 {
#                     center: [38.4237, 27.1428],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f5ebfdf825a476a8d17c0d69d237ed5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_3f5ebfdf825a476a8d17c0d69d237ed5.addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#             var circle_marker_3d2211be5519dcaa15c93e9a1856d77d = L.circleMarker(
#                 [38.3659695, 27.1447331],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_75db6bcc6934d54b818b6557c95ca7eb = L.circleMarker(
#                 [38.4006306, 27.1203472],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_37f3cf9f0339f05c0b9a28840f2651e6 = L.circleMarker(
#                 [38.4263328, 27.1393993],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_ac1020f35343b45e7a465d7dcbf10af3 = L.circleMarker(
#                 [38.4173447, 27.131525],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_6332889f768002e9493542649e75952c = L.circleMarker(
#                 [38.3726707, 27.1649462],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_d323183d2159de5e1fc69297f277aa0d = L.circleMarker(
#                 [38.4463258, 27.1738927],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_e494a24aa7e6a700f70c77244dc66767);
#
#
#             var circle_marker_1cc996356d9

# %% [markdown]
# ## Defining lists and parameters

# %%
# Set of Potential Stations 
K = ["ÇEŞME", "URLA", "SEFERIHISAR", "GAZIEMIR", "TAHTALIÇAY", "OTOYOLAYR",  "KARŞIYAKA", "BELEVI", "GERMENCIK", "ŞEVKETIYE"]

# Set of all OD pairs
Q = ["ÇEŞME-ALAÇATI-ZEYTINLER", "ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN", "ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA", "ALAÇATI-ZEYTNILER-KARABURUN", "ALAÇATI-ZEYTNILER-KARABURUN-URLA", "ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR", "ZEYTNILER-KARABURUN-URLA", "ZEYTNILER-KARABURUN-URLA-SEFERIHISAR", "ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK", "KARABURUN-URLA-SEFERIHISAR", "KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK", "KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA", "URLA-SEFERIHISAR-ŞEHITLIK", "URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA", "URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR", "SEFERIHISAR-ŞEHITLIK-BALÇOVA", "SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR", "SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR", "ŞEHITLIK-BALÇOVA-GAZIEMIR", "ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR", "ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT", "BALÇOVA-GAZIEMIR-OTOYOLAYR", "BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT", "BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY", "ŞEVKETİYE-GERMENCIK-BELEVI", "ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI", "ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY"]
# flow volume on the OD pair qQ = ["ALAÇATI-KARABURUN", "ALAÇATI-KARABURUN-SEFERHISAR", "ALAÇATI-KARABURUN-SEFERHISAR-OTOYOL AYR.", "KARABURUN-SEFERHISAR", "KARABURUN-SEFERHISAR-OTOYOL AYR.", "KARABURUN-SEFERHISAR-OTOYOL AYR.-ÜNIVERSITE AYR.", "SEFERHISAR-OTOYOL AYR.", "SEFERHISAR-OTOYOL AYR.-ÜNIVERSITE AYR.", "SEFERHISAR-OTOYOL AYR.-ÜNIVERSITE AYR.-TORBALI", "OTOYOL AYR.-ÜNIVERSITE AYR", "OTOYOL AYR.-ÜNIVERSITE AYR-TORBALI", "OTOYOL AYR.-ÜNIVERSITE AYR-TORBALI-GERMENCIK", "ÜNIVERSITE AYR.-TORBALI", "ÜNIVERSITE AYR.-TORBALI-GERMENCIK", "ÜNIVERSITE AYR.-TORBALI-GERMENCIK-SEVKETIYE"
f = [8235, 9173, 9926, 11606, 12285, 18276, 12520, 22538, 19950, 22917, 31085, 32599, 33345, 37703, 41779, 45495, 48642, 53071, 50777, 55778, 55715, 59881, 58808, 55010, 24441, 27419, 30014]
# the number of stations to be opened
P = 4
C ={}
for k in K: 
    for q in Q:
        if k in q:
            C[k,q]= 1
        else:
            C[k,q] = 0
C
# Out:
# {('ÇEŞME', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 1,
#  ('ÇEŞME', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 1,
#  ('ÇEŞME', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 1,
#  ('ÇEŞME', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('ÇEŞME', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('ÇEŞME', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('ÇEŞME', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('ÇEŞME', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('ÇEŞME', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('ÇEŞME', 'KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('ÇEŞME', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('ÇEŞME', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('ÇEŞME', 'URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('ÇEŞME', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('ÇEŞME', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('ÇEŞME', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('ÇEŞME', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('ÇEŞME', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('ÇEŞME', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('ÇEŞME', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('ÇEŞME', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('ÇEŞME', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('ÇEŞME', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('ÇEŞME', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 0,
#  ('ÇEŞME', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 0,
#  ('ÇEŞME', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 0,
#  ('ÇEŞME', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 0,
#  ('URLA', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('URLA', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('URLA', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 1,
#  ('URLA', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('URLA', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 1,
#  ('URLA', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 1,
#  ('URLA', 'ZEYTNILER-KARABURUN-URLA'): 1,
#  ('URLA', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 1,
#  ('URLA', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 1,
#  ('URLA', 'KARABURUN-URLA-SEFERIHISAR'): 1,
#  ('URLA', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 1,
#  ('URLA', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 1,
#  ('URLA', 'URLA-SEFERIHISAR-ŞEHITLIK'): 1,
#  ('URLA', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 1,
#  ('URLA', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 1,
#  ('URLA', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('URLA', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('URLA', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('URLA', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('URLA', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('URLA', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('URLA', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('URLA', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('URLA', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 0,
#  ('URLA', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 0,
#  ('URLA', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 0,
#  ('URLA', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 0,
#  ('SEFERIHISAR', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('SEFERIHISAR', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('SEFERIHISAR', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 0,
#  ('SEFERIHISAR', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('SEFERIHISAR', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('SEFERIHISAR', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 1,
#  ('SEFERIHISAR', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('SEFERIHISAR', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 1,
#  ('SEFERIHISAR', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 1,
#  ('SEFERIHISAR', 'KARABURUN-URLA-SEFERIHISAR'): 1,
#  ('SEFERIHISAR', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 1,
#  ('SEFERIHISAR', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 1,
#  ('SEFERIHISAR', 'URLA-SEFERIHISAR-ŞEHITLIK'): 1,
#  ('SEFERIHISAR', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 1,
#  ('SEFERIHISAR', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 1,
#  ('SEFERIHISAR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 1,
#  ('SEFERIHISAR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 1,
#  ('SEFERIHISAR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 1,
#  ('SEFERIHISAR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('SEFERIHISAR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('SEFERIHISAR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('SEFERIHISAR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('SEFERIHISAR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('SEFERIHISAR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 0,
#  ('SEFERIHISAR', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 0,
#  ('SEFERIHISAR', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 0,
#  ('SEFERIHISAR', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 0,
#  ('GAZIEMIR', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('GAZIEMIR', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('GAZIEMIR', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 0,
#  ('GAZIEMIR', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('GAZIEMIR', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('GAZIEMIR', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('GAZIEMIR', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('GAZIEMIR', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('GAZIEMIR', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('GAZIEMIR', 'KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('GAZIEMIR', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('GAZIEMIR', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('GAZIEMIR', 'URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('GAZIEMIR', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('GAZIEMIR', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 1,
#  ('GAZIEMIR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('GAZIEMIR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 1,
#  ('GAZIEMIR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 1,
#  ('GAZIEMIR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 1,
#  ('GAZIEMIR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 1,
#  ('GAZIEMIR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 1,
#  ('GAZIEMIR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 1,
#  ('GAZIEMIR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 1,
#  ('GAZIEMIR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 1,
#  ('GAZIEMIR', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 0,
#  ('GAZIEMIR', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 0,
#  ('GAZIEMIR', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 0,
#  ('TAHTALIÇAY', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('TAHTALIÇAY', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('TAHTALIÇAY', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 0,
#  ('TAHTALIÇAY', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('TAHTALIÇAY', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('TAHTALIÇAY', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('TAHTALIÇAY', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('TAHTALIÇAY', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('TAHTALIÇAY', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('TAHTALIÇAY', 'KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('TAHTALIÇAY', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('TAHTALIÇAY', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('TAHTALIÇAY', 'URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('TAHTALIÇAY', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('TAHTALIÇAY', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('TAHTALIÇAY', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('TAHTALIÇAY', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('TAHTALIÇAY', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('TAHTALIÇAY', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('TAHTALIÇAY', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('TAHTALIÇAY', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('TAHTALIÇAY', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('TAHTALIÇAY', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('TAHTALIÇAY', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 1,
#  ('TAHTALIÇAY', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 0,
#  ('TAHTALIÇAY', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 0,
#  ('TAHTALIÇAY', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 0,
#  ('OTOYOLAYR', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('OTOYOLAYR', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('OTOYOLAYR', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 0,
#  ('OTOYOLAYR', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('OTOYOLAYR', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('OTOYOLAYR', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('OTOYOLAYR', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('OTOYOLAYR', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('OTOYOLAYR', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('OTOYOLAYR', 'KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('OTOYOLAYR', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('OTOYOLAYR', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('OTOYOLAYR', 'URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('OTOYOLAYR', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('OTOYOLAYR', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('OTOYOLAYR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('OTOYOLAYR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('OTOYOLAYR', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 1,
#  ('OTOYOLAYR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('OTOYOLAYR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 1,
#  ('OTOYOLAYR', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 1,
#  ('OTOYOLAYR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 1,
#  ('OTOYOLAYR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 1,
#  ('OTOYOLAYR', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 1,
#  ('OTOYOLAYR', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 0,
#  ('OTOYOLAYR', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 0,
#  ('OTOYOLAYR', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 0,
#  ('KARŞIYAKA', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('KARŞIYAKA', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('KARŞIYAKA', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 0,
#  ('KARŞIYAKA', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('KARŞIYAKA', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('KARŞIYAKA', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('KARŞIYAKA', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('KARŞIYAKA', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('KARŞIYAKA', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('KARŞIYAKA', 'KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('KARŞIYAKA', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('KARŞIYAKA', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('KARŞIYAKA', 'URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('KARŞIYAKA', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('KARŞIYAKA', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('KARŞIYAKA', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('KARŞIYAKA', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('KARŞIYAKA', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('KARŞIYAKA', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('KARŞIYAKA', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('KARŞIYAKA', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('KARŞIYAKA', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('KARŞIYAKA', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('KARŞIYAKA', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 0,
#  ('KARŞIYAKA', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 0,
#  ('KARŞIYAKA', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 0,
#  ('KARŞIYAKA', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 0,
#  ('BELEVI', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('BELEVI', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('BELEVI', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 0,
#  ('BELEVI', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('BELEVI', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('BELEVI', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('BELEVI', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('BELEVI', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('BELEVI', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('BELEVI', 'KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('BELEVI', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('BELEVI', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('BELEVI', 'URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('BELEVI', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('BELEVI', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('BELEVI', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('BELEVI', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('BELEVI', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('BELEVI', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('BELEVI', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('BELEVI', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('BELEVI', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('BELEVI', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('BELEVI', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 0,
#  ('BELEVI', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 1,
#  ('BELEVI', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 1,
#  ('BELEVI', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 1,
#  ('GERMENCIK', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('GERMENCIK', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('GERMENCIK', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 0,
#  ('GERMENCIK', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('GERMENCIK', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('GERMENCIK', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('GERMENCIK', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('GERMENCIK', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('GERMENCIK', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('GERMENCIK', 'KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('GERMENCIK', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('GERMENCIK', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('GERMENCIK', 'URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('GERMENCIK', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('GERMENCIK', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('GERMENCIK', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('GERMENCIK', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('GERMENCIK', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('GERMENCIK', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('GERMENCIK', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('GERMENCIK', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('GERMENCIK', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('GERMENCIK', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('GERMENCIK', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 0,
#  ('GERMENCIK', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 1,
#  ('GERMENCIK', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 1,
#  ('GERMENCIK', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 1,
#  ('ŞEVKETIYE', 'ÇEŞME-ALAÇATI-ZEYTINLER'): 0,
#  ('ŞEVKETIYE', 'ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN'): 0,
#  ('ŞEVKETIYE', 'ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA'): 0,
#  ('ŞEVKETIYE', 'ALAÇATI-ZEYTNILER-KARABURUN'): 0,
#  ('ŞEVKETIYE', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA'): 0,
#  ('ŞEVKETIYE', 'ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('ŞEVKETIYE', 'ZEYTNILER-KARABURUN-URLA'): 0,
#  ('ŞEVKETIYE', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('ŞEVKETIYE', 'ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('ŞEVKETIYE', 'KARABURUN-URLA-SEFERIHISAR'): 0,
#  ('ŞEVKETIYE', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('ŞEVKETIYE', 'KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('ŞEVKETIYE', 'URLA-SEFERIHISAR-ŞEHITLIK'): 0,
#  ('ŞEVKETIYE', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('ŞEVKETIYE', 'URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('ŞEVKETIYE', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA'): 0,
#  ('ŞEVKETIYE', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('ŞEVKETIYE', 'SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('ŞEVKETIYE', 'ŞEHITLIK-BALÇOVA-GAZIEMIR'): 0,
#  ('ŞEVKETIYE', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('ŞEVKETIYE', 'ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('ŞEVKETIYE', 'BALÇOVA-GAZIEMIR-OTOYOLAYR'): 0,
#  ('ŞEVKETIYE', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT'): 0,
#  ('ŞEVKETIYE', 'BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY'): 0,
#  ('ŞEVKETIYE', 'ŞEVKETİYE-GERMENCIK-BELEVI'): 0,
#  ('ŞEVKETIYE', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI'): 0,
#  ('ŞEVKETIYE', 'ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY'): 0}

# %% [markdown]
# ## Defining variables

# %%
# y = 1 If fq is captured otherwise 0
y = {}
for q in Q:
    y[q] = solver.BoolVar(f'y_{q}')
# x = 1 if a station is located at k otherwise 0
x = {}
for k in K:
    x[k] = solver.BoolVar(f'x_{k}')

# %% [markdown]
# ## Defining constrains

# %%
#prevents the capturing of path q, unless a suitable combination of stations is selected.
for q in Q:
    solver.Add(solver.Sum(C[(k, q)] * x[k] for k in K) >= y[q])

#ensures that the number of opened stations equals to p
solver.Add(solver.Sum(x[k] for k in K) == P)
# Out:
# <ortools.linear_solver.pywraplp.Constraint; proxy of <Swig Object of type 'operations_research::MPConstraint *' at 0x79e56c5e6e80> >

# %% [markdown]
# ## Defining objective function

# %%
solver.Maximize(solver.Sum(f[i] * y[q] for i, q in enumerate(Q)))
status = solver.Solve()
if status == pywraplp.Solver.OPTIMAL:
    print('Objective value =', solver.Objective().Value())
    for i in Q:
        print(y[i].name(), ' = ', y[i].solution_value())
    print()
    print('Problem solved in %f milliseconds' % solver.wall_time())
    print('Problem solved in %d iterations' % solver.iterations())
    print('Problem solved in %d branch-and-bound nodes' % solver.nodes())
else:
    print('The problem does not have an optimal solution.')
# Out:
# Objective value = 859974.0
# y_ÇEŞME-ALAÇATI-ZEYTINLER  =  0.0
# y_ÇEŞME-ALAÇATI-ZEYTINLER-KARABURUN  =  0.0
# y_ÇEŞME-ALAÇATI-ZETINLER-KARABURUN-URLA  =  1.0
# y_ALAÇATI-ZEYTNILER-KARABURUN  =  0.0
# y_ALAÇATI-ZEYTNILER-KARABURUN-URLA  =  1.0
# y_ALAÇATI-ZEYTNILER-KARABURUN-URLA-SEFERIHISAR  =  1.0
# y_ZEYTNILER-KARABURUN-URLA  =  1.0
# y_ZEYTNILER-KARABURUN-URLA-SEFERIHISAR  =  1.0
# y_ZEYTNILER-KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK  =  1.0
# y_KARABURUN-URLA-SEFERIHISAR  =  1.0
# y_KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK  =  1.0
# y_KARABURUN-URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA  =  1.0
# y_URLA-SEFERIHISAR-ŞEHITLIK  =  1.0
# y_URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA  =  1.0
# y_URLA-SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR  =  1.0
# y_SEFERIHISAR-ŞEHITLIK-BALÇOVA  =  1.0
# y_SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR  =  1.0
# y_SEFERIHISAR-ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR  =  1.0
# y_ŞEHITLIK-BALÇOVA-GAZIEMIR  =  1.0
# y_ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR  =  1.0
# y_ŞEHITLIK-BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT  =  1.0
# y_BALÇOVA-GAZIEMIR-OTOYOLAYR  =  1.0
# y_BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT  =  1.0
# y_BALÇOVA-GAZIEMIR-OTOYOLAYR-IŞIKKENT-TAHTALIÇAY  =  1.0
# y_ŞEVKETİYE-GERMENCIK-BELEVI  =  1.0
# y_ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI  =  1.0
# y_ŞEVKETİYE-GERMENCIK-BELEVI-TORBALI-TATHALIÇAY  =  1.0
#
# Problem solved in 4011.000000 milliseconds
# Problem solved in 2 iterations
# Problem solved in 1 branch-and-bound nodes

# %%
for key, val in x.items():
    print(f"{key}: {val.solution_value()}")
# Out:
# ÇEŞME: 0.0
# URLA: 1.0
# SEFERIHISAR: 1.0
# GAZIEMIR: 1.0
# TAHTALIÇAY: 0.0
# OTOYOLAYR: 0.0
# KARŞIYAKA: 0.0
# BELEVI: 1.0
# GERMENCIK: 0.0
# ŞEVKETIYE: 0.0

# %%
sum(f)
# Out:
# 888988

# %%
solver.Objective().Value()/sum(f)
# Out:
# 0.9673628890378723
